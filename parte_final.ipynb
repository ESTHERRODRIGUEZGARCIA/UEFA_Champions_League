# %%
#semis_data = datos_gradio/global_temp_con_puntos.csv
import pandas as pd

semis_filtered = pd.read_csv('datos_gradio/datos_semis.csv')
print(semis_filtered.head())
# Out:
#                 equipo  media_goles_ataque  tiros_puerta  penaltis_favor  \
# 0          Real Madrid                 2.2          12.6             0.1
# 1        Bayern Munich                 1.8          10.4             0.2
# 2    Borussia Dortmund                 1.5          10.1             0.1
# 3  Paris Saint-Germain                 1.9          12.3             0.3
#
#    corners  faltas_recibidas  fuera_juego  goles_recibidos  \
# 0      6.2              10.1          1.5              1.2
# 1      5.5               9.9          1.8              0.9
# 2      5.7               9.5          1.7              0.9
# 3      7.4              10.9          3.0              1.3
#
#    tiros_puerta_recibidos  penalti_contra  posesion
# 0                    14.5             0.2        52
# 1                     9.6             0.2        57
# 2                    14.3             0.3        48
# 3                    11.3             0.0        65

# %%
global_temp_filtered = pd.read_csv('datos_gradio/global_temp_con_puntos.csv')
print(global_temp_filtered.head())
# Out:
#       SEASON                  equipo  p_jugados  p_ganados  p_empatados  \
# 0  2016-2017                FC Basel          6          0            2
# 1  2016-2017  PFC Ludogorets Razgrad          6          0            3
# 2  2016-2017     Paris Saint-Germain          8          4            3
# 3  2016-2017              Arsenal FC          8          4            2
# 4  2016-2017             Dinamo Kiev          6          1            2
#
#    p_perdidos  goles_a_favor  goles_en_contra  puntos
# 0           4              3               12       2
# 1           3              6               15       3
# 2           1             18               13      15
# 3           2             20               16      14
# 4           3              8                6       5

# %%
# Combinar los datos de semifinales y globales en un solo DataFrame
combined_data = pd.merge(semis_filtered, global_temp_filtered, on='equipo', how='inner')

# Mostrar los datos combinados para revisión
combined_data
# Out:
#                  equipo  media_goles_ataque  tiros_puerta  penaltis_favor  \
# 0           Real Madrid                 2.2          12.6             0.1
# 1           Real Madrid                 2.2          12.6             0.1
# 2           Real Madrid                 2.2          12.6             0.1
# 3           Real Madrid                 2.2          12.6             0.1
# 4           Real Madrid                 2.2          12.6             0.1
# 5           Real Madrid                 2.2          12.6             0.1
# 6           Real Madrid                 2.2          12.6             0.1
# 7     Borussia Dortmund                 1.5          10.1             0.1
# 8     Borussia Dortmund                 1.5          10.1             0.1
# 9     Borussia Dortmund                 1.5          10.1             0.1
# 10    Borussia Dortmund                 1.5          10.1             0.1
# 11    Borussia Dortmund                 1.5          10.1             0.1
# ...

# %%
# Combinar los datos de semifinales y globales en un solo DataFrame
combined_data = pd.merge(semis_filtered, global_temp_filtered, on='equipo', how='inner')

# Mostrar los datos combinados para revisión
combined_data.head()
# Out:
#     SEASON_x               equipo  p_jugados_x  p_ganados_x  p_empatados_x  \
# 0  2016-2017  Paris Saint-Germain            8            4              3
# 1  2016-2017  Paris Saint-Germain            8            4              3
# 2  2016-2017  Paris Saint-Germain            8            4              3
# 3  2016-2017  Paris Saint-Germain            8            4              3
# 4  2016-2017  Paris Saint-Germain            8            4              3
#
#    p_perdidos_x  goles_a_favor_x  goles_en_contra_x  puntos_x   SEASON_y  \
# 0             1               18                 13        15  2016-2017
# 1             1               18                 13        15  2017-2018
# 2             1               18                 13        15  2018-2019
# 3             1               18                 13        15  2019-2020
# 4             1               18                 13        15  2020-2021
#
# ...
